# %% [markdown]
# # 柱状图

# %%
x = np.arange(10)
y = np.random.randint(0,30,10)
plt.bar(x, y)
plt.show()

# %% [markdown]
# # 饼状图

# %%
x = np.random.randint(1, 10, 3)
plt.pie(x)
plt.show()

# %% [markdown]
# # 折线图

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

x=np.arange(9)
y=np.sin(x)
z=np.cos(x)

# %% [markdown]
# ## marker数据点样式，linewidth线宽，linestyle线型样式，color颜色

# %%
plt.plot(x,y,linewidth=3,linestyle="--",color="orange")

# %%
plt.plot(x,z)

# %%
plt.title("matplotlib")
# Out:
# Text(0.5, 1.0, 'matplotlib')

# %%
plt.xlabel("height")
plt.ylabel("width")
# Out:
# Text(0, 0.5, 'width')

# %% [markdown]
# ## 设置图例

# %%
plt.plot(x, y, marker="*", linewidth=3, linestyle="--", color="orange")
plt.plot(x, z)
plt.title("matplotlib")
plt.xlabel("height")
plt.ylabel("width")

plt.legend(["Y","Z"],loc="upper right")

# %%
plt.grid(True)

# %%
plt.plot(x, y, marker="*", linewidth=3, linestyle="--", color="orange")
plt.plot(x, z)
plt.title("matplotlib")
plt.xlabel("height")
plt.ylabel("width")

plt.legend(["Y","Z"],loc="upper right")
plt.grid(True)
plt.show()

# %% [markdown]
# # 散点图

# %%
x = np.random.rand(10)
y = np.random.rand(10)
plt.scatter(x,y)
plt.show()

# %% [markdown]
# # 直方图

# %%
mean,sigma=0,1
x=mean+sigma*np.random.randn(1000)
plt.hist(x,50)
plt.show()

# %% [markdown]
# # 给定数据和任务，选择合适的表示方法进行可视化展示

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data=pd.read_csv('adult.csv',header=None, names=["age","工作类型","fnlwgt","education","学历编号","婚姻状况","occupation","社会关系","种族","性别","capital_gain","资本支出","worktime_per_week","祖国","salary"], encoding='utf_8')
data

data_clean=data[["education","occupation","capital_gain","worktime_per_week","salary"]]
data_clean
data_clean.to_excel("data_clean.xls", encoding = 'utf-8')

# %%
data_clean['salary'].value_counts().values
# Out:
# array([24720,  7841], dtype=int64)

# %%
data_clean['education'].value_counts().index
# Out:
# Index([' HS-grad', ' Some-college', ' Bachelors', ' Masters', ' Assoc-voc',
#        ' 11th', ' Assoc-acdm', ' 10th', ' 7th-8th', ' Prof-school', ' 9th',
#        ' 12th', ' Doctorate', ' 5th-6th', ' 1st-4th', ' Preschool'],
#       dtype='object')

# %%
data_clean['occupation'].value_counts().index
# Out:
# Index([' Prof-specialty', ' Craft-repair', ' Exec-managerial', ' Adm-clerical',
#        ' Sales', ' Other-service', ' Machine-op-inspct', ' ?',
#        ' Transport-moving', ' Handlers-cleaners', ' Farming-fishing',
#        ' Tech-support', ' Protective-serv', ' Priv-house-serv',
#        ' Armed-Forces'],
#       dtype='object')

# %% [markdown]
# #删除/选取某列含有特定数值的行
# #df1=df1[df1['A'].isin([1])]
# #df1[df1['A'].isin([1])]  选取df1中A列包含数字1的行

# %%
data_clean['education'][56]
# Out:
# ' 5th-6th'

# %%
data_clean_edu_sala=data_clean[data_clean.education==data_clean['education'][0]]
bachelor_sala1_less=data_clean_edu_sala.salary.value_counts()[0:1]
bachelor_sala1_greater=data_clean_edu_sala.salary.value_counts()[1:]

# %%
print(data_clean[data_clean.education==data_clean['education'][2]])
print(data_clean[data_clean.education==data_clean['education'][10]])
print(data_clean[data_clean.education==data_clean['education'][0]])
print(data_clean[data_clean.education==data_clean['education'][5]])
print(data_clean[data_clean.education==data_clean['education'][14]])
print(data_clean[data_clean.education==data_clean['education'][3]])
print(data_clean[data_clean.education==data_clean['education'][13]])
print(data_clean[data_clean.education==data_clean['education'][77]])
print(data_clean[data_clean.education==data_clean['education'][15]])
print(data_clean[data_clean.education==data_clean['education'][52]])
print(data_clean[data_clean.education==data_clean['education'][6]])
print(data_clean[data_clean.education==data_clean['education'][415]])
print(data_clean[data_clean.education==data_clean['education'][20]])
print(data_clean[data_clean.education==data_clean['education'][56]])
print(data_clean[data_clean.education==data_clean['education'][160]])
print(data_clean[data_clean.education==data_clean['education'][224]])
# Out:
#       education          occupation  capital_gain  worktime_per_week  salary
# 2       HS-grad   Handlers-cleaners             0                 40   <=50K
# 7       HS-grad     Exec-managerial             0                 45    >50K
# 16      HS-grad     Farming-fishing             0                 35   <=50K
# 17      HS-grad   Machine-op-inspct             0                 40   <=50K
# 21      HS-grad       Other-service             0                 20   <=50K
# 24      HS-grad        Tech-support             0                 40   <=50K
# 26      HS-grad        Craft-repair             0                 40   <=50K
# 28      HS-grad     Exec-managerial             0                 80   <=50K
# 29      HS-grad        Craft-repair             0                 40   <=50K
# 37      HS-grad        Adm-clerical             0                 25   <=50K
# 43      HS-grad        Adm-clerical             0                 40   <=50K
# ...

# %%
one_less=data_clean[data_clean.education==data_clean['education'][2]].salary.value_counts()[0:1].values
one_greater=data_clean[data_clean.education==data_clean['education'][2]].salary.value_counts()[1:].values
two_less=data_clean[data_clean.education==data_clean['education'][10]].salary.value_counts()[0:1].values
two_greater=data_clean[data_clean.education==data_clean['education'][10]].salary.value_counts()[1:].values
three_less=data_clean[data_clean.education==data_clean['education'][0]].salary.value_counts()[0:1].values
three_greater=data_clean[data_clean.education==data_clean['education'][0]].salary.value_counts()[1:].values
four_less=data_clean[data_clean.education==data_clean['education'][5]].salary.value_counts()[0:1].values
four_greater=data_clean[data_clean.education==data_clean['education'][5]].salary.value_counts()[1:].values
five_less=data_clean[data_clean.education==data_clean['education'][14]].salary.value_counts()[0:1].values
five_greater=data_clean[data_clean.education==data_clean['education'][14]].salary.value_counts()[1:].values
six_less=data_clean[data_clean.education==data_clean['education'][3]].salary.value_counts()[0:1].values
six_greater=data_clean[data_clean.education==data_clean['education'][3]].salary.value_counts()[1:].values
seven_less=data_clean[data_clean.education==data_clean['education'][13]].salary.value_counts()[0:1].values
seven_greater=data_clean[data_clean.education==data_clean['education'][13]].salary.value_counts()[1:].values
eight_less=data_clean[data_clean.education==data_clean['education'][77]].salary.value_counts()[0:1].values
eight_greater=data_clean[data_clean.education==data_clean['education'][77]].salary.value_counts()[1:].values
nine_less=data_clean[data_clean.education==data_clean['education'][15]].salary.value_counts()[0:1].values
nine_greater=data_clean[data_clean.education==data_clean['education'][15]].salary.value_counts()[1:].values
ten_less=data_clean[data_clean.education==data_clean['education'][52]].salary.value_counts()[0:1].values
ten_greater=data_clean[data_clean.education==data_clean['education'][52]].salary.value_counts()[1:].values
eleven_less=data_clean[data_clean.education==data_clean['education'][6]].salary.value_counts()[0:1].values
eleven_greater=data_clean[data_clean.education==data_clean['education'][6]].salary.value_counts()[1:].values
twelve_less=data_clean[data_clean.education==data_clean['education'][415]].salary.value_counts()[0:1].values
twelve_greater=data_clean[data_clean.education==data_clean['education'][415]].salary.value_counts()[1:].values
thirteen_less=data_clean[data_clean.education==data_clean['education'][20]].salary.value_counts()[0:1].values
thirteen_greater=data_clean[data_clean.education==data_clean['education'][20]].salary.value_counts()[1:].values
fourteen_less=data_clean[data_clean.education==data_clean['education'][56]].salary.value_counts()[0:1].values
fourteen_greater=data_clean[data_clean.education==data_clean['education'][56]].salary.value_counts()[1:].values
fifteen_less=data_clean[data_clean.education==data_clean['education'][160]].salary.value_counts()[0:1].values
fifteen_greater=data_clean[data_clean.education==data_clean['education'][160]].salary.value_counts()[1:].values
sixteen_less=data_clean[data_clean.education==data_clean['education'][224]].salary.value_counts()[0:1].values
sixteen_greater=data_clean[data_clean.education==data_clean['education'][224]].salary.value_counts()[1:].values

# %%
fig2_less=np.array([one_less,two_less,three_less,four_less,five_less,six_less,seven_less,eight_less,nine_less,ten_less,eleven_less,twelve_less,thirteen_less,fourteen_less,fifteen_less,sixteen_less])
fig2_less=pd.DataFrame(fig2_less)

# %%
fig2_greater=np.array([one_greater,two_greater,three_greater,four_greater,five_greater,six_greater,seven_greater,eight_greater,nine_greater,ten_greater,eleven_greater,twelve_greater,thirteen_greater,fourteen_greater,fifteen_greater,sixteen_greater])
fig2_greater
# Out:
# array([array([1675], dtype=int64), array([1387], dtype=int64),
#        array([2221], dtype=int64), array([764], dtype=int64),
#        array([361], dtype=int64), array([60], dtype=int64),
#        array([265], dtype=int64), array([62], dtype=int64),
#        array([40], dtype=int64), array([153], dtype=int64),
#        array([27], dtype=int64), array([33], dtype=int64),
#        array([107], dtype=int64), array([16], dtype=int64),
#        array([6], dtype=int64), array([], dtype=int64)], dtype=object)

# %%
one_less=data_clean[data_clean.occupation==data_clean['occupation'][4]].salary.value_counts()[0:1].values
one_greater=data_clean[data_clean.occupation==data_clean['occupation'][4]].salary.value_counts()[1:].values
two_less=data_clean[data_clean.occupation==data_clean['occupation'][14]].salary.value_counts()[0:1].values
two_greater=data_clean[data_clean.occupation==data_clean['occupation'][14]].salary.value_counts()[1:].values
three_less=data_clean[data_clean.occupation==data_clean['occupation'][1]].salary.value_counts()[0:1].values
three_greater=data_clean[data_clean.occupation==data_clean['occupation'][1]].salary.value_counts()[1:].values
four_less=data_clean[data_clean.occupation==data_clean['occupation'][0]].salary.value_counts()[0:1].values
four_greater=data_clean[data_clean.occupation==data_clean['occupation'][0]].salary.value_counts()[1:].values
five_less=data_clean[data_clean.occupation==data_clean['occupation'][13]].salary.value_counts()[0:1].values
five_greater=data_clean[data_clean.occupation==data_clean['occupation'][13]].salary.value_counts()[1:].values
six_less=data_clean[data_clean.occupation==data_clean['occupation'][6]].salary.value_counts()[0:1].values
six_greater=data_clean[data_clean.occupation==data_clean['occupation'][6]].salary.value_counts()[1:].values
seven_less=data_clean[data_clean.occupation==data_clean['occupation'][17]].salary.value_counts()[0:1].values
seven_greater=data_clean[data_clean.occupation==data_clean['occupation'][17]].salary.value_counts()[1:].values
eight_less=data_clean[data_clean.occupation==data_clean['occupation'][27]].salary.value_counts()[0:1].values
eight_greater=data_clean[data_clean.occupation==data_clean['occupation'][27]].salary.value_counts()[1:].values
nine_less=data_clean[data_clean.occupation==data_clean['occupation'][15]].salary.value_counts()[0:1].values
nine_greater=data_clean[data_clean.occupation==data_clean['occupation'][15]].salary.value_counts()[1:].values
ten_less=data_clean[data_clean.occupation==data_clean['occupation'][2]].salary.value_counts()[0:1].values
ten_greater=data_clean[data_clean.occupation==data_clean['occupation'][2]].salary.value_counts()[1:].values
eleven_less=data_clean[data_clean.occupation==data_clean['occupation'][16]].salary.value_counts()[0:1].values
eleven_greater=data_clean[data_clean.occupation==data_clean['occupation'][16]].salary.value_counts()[1:].values
twelve_less=data_clean[data_clean.occupation==data_clean['occupation'][24]].salary.value_counts()[0:1].values
twelve_greater=data_clean[data_clean.occupation==data_clean['occupation'][24]].salary.value_counts()[1:].values
thirteen_less=data_clean[data_clean.occupation==data_clean['occupation'][30]].salary.value_counts()[0:1].values
thirteen_greater=data_clean[data_clean.occupation==data_clean['occupation'][30]].salary.value_counts()[1:].values
fourteen_less=data_clean[data_clean.occupation==data_clean['occupation'][536]].salary.value_counts()[0:1].values
fourteen_greater=data_clean[data_clean.occupation==data_clean['occupation'][536]].salary.value_counts()[1:].values
fifteen_less=data_clean[data_clean.occupation==data_clean['occupation'][442]].salary.value_counts()[0:1].values
fifteen_greater=data_clean[data_clean.occupation==data_clean['occupation'][442]].salary.value_counts()[1:].values

# %%
data_clean['occupation'][4]
# Out:
# ' Prof-specialty'

# %%
fig3_less=np.array([one_less,two_less,three_less,four_less,five_less,six_less,seven_less,eight_less,nine_less,ten_less,eleven_less,twelve_less,thirteen_less,fourteen_less,fifteen_less])
fig3_less=pd.DataFrame(fig3_less)
fig3_less.values
# Out:
# array([[2281],
#        [3170],
#        [2098],
#        [3263],
#        [2667],
#        [3158],
#        [1752],
#        [1652],
#        [1277],
#        [1284],
#        [ 879],
#        [ 645],
#        [ 438],
#        [ 148],
#        [   8]], dtype=int64)

# %%
fig3_greater=np.array([one_greater,two_greater,three_greater,four_greater,five_greater,six_greater,seven_greater,eight_greater,nine_greater,ten_greater,eleven_greater,twelve_greater,thirteen_greater,fourteen_greater,fifteen_greater])
fig3_greater=pd.DataFrame(fig3_greater)
fig3_greater.values
# Out:
# array([[1859],
#        [ 929],
#        [1968],
#        [ 507],
#        [ 983],
#        [ 137],
#        [ 250],
#        [ 191],
#        [ 320],
#        [  86],
#        [ 115],
#        [ 283],
#        [ 211],
#        [   1],
#        [   1]], dtype=int64)

# %%
plt.figure(figsize=(10,8))
data_clean['salary'].value_counts().plot(kind='pie')
plt.title('薪资水平统计图',fontsize=20)
plt.ylabel('')
plt.rcParams['font.sans-serif']=['Dengxian']
plt.show()


plt.figure(figsize=(15, 6), dpi=80)
x=range(len(data_clean['education'].value_counts().index))
y1=8826,3170,2098,3263,2667,3158,1752,1652,1277,1284,879,645,438,317,162,51
y2=1675,1387,2221,764,361,60,265,62,40,153,27,33,107,16,6,0
plt.bar(x,y1, width=0.2)
plt.bar([i + 0.2 for i in x],y2, width=0.2)
plt.xticks([i + 0.1 for i in x], data_clean['education'].value_counts().index)
plt.title('学历与收入的关系统计图',fontsize=20)
plt.show()


plt.figure(figsize=(20, 6), dpi=80)
x=range(len(data_clean['occupation'].value_counts().index))
y1=2281,3170,2098,3263,2667,3158,1752,1652,1277,1284,879,645,438,148,8
y2=1859, 929,1968,507,983,137,250,191,320,86,115,283,211,1,1
plt.bar(x,y1, width=0.2)
plt.bar([i + 0.2 for i in x],y2, width=0.2)
plt.xticks([i + 0.1 for i in x], data_clean['occupation'].value_counts().index)
plt.title('职业与收入的关系统计图',fontsize=20)
plt.show()


plt.figure(figsize=(20,8))
x=data_clean['worktime_per_week'].value_counts().index
y=data_clean['worktime_per_week'].value_counts().values
plt.scatter(x,y)
plt.xticks(data_clean['worktime_per_week'].value_counts().index)
plt.title('所统计人口每小时工作时间的分布图',fontsize=20)
plt.xlabel('worktime_per_week',fontsize=12)
plt.ylabel('人数',fontsize=12)
plt.show()


plt.figure(figsize=(20,8))
x=range(len(data_clean['worktime_per_week'].value_counts().index))
y=data_clean['worktime_per_week'].value_counts().values
plt.plot(x,y)
plt.title('每周工作时间与资本收益（capital-gain）之间的关系图',fontsize=20)
plt.show()
